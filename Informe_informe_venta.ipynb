# %% [markdown]
# <a href="https://colab.research.google.com/github/Tomytool/Boton_interactivo/blob/master/Informe_informe_venta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df_ventas=pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Invenstigacion_plan/grafico diario venta.xlsx", index_col=0 )
df_ventas
# Out:
#             Plan Venta M$  Plan Venta Empresa M$  Plan Venta Retail M$  \
# Fecha
# 2022-08-01      38957.947              26412.792             12545.155
# 2022-08-02      38054.592              19838.752             18215.840
# 2022-08-03      38091.451              19545.690             18545.761
# 2022-08-04      38626.320              19812.466             18813.854
# 2022-08-05      38318.799              17945.699             20373.100
# 2022-08-06      18903.028               2764.498             16138.530
# 2022-08-08      36958.280              17658.409             19299.871
# 2022-08-09      36058.224              20331.503             15726.721
# 2022-08-10      36090.792              19667.967             16422.825
# 2022-08-11      36624.545              20769.082             15855.463
# 2022-08-12      36317.172              17611.526             18705.646
# 2022-08-13      18903.028               2764.498             16138.530
# ...

# %%
df_ventas[df_ventas.isna()]= 0
# df_ventas

# %%
sns.lineplot(data=df_ventas, x='Fecha', y="Plan Venta M$")
sns.lineplot(data=df_ventas, x='Fecha', y="Venta M$ Empresa")
